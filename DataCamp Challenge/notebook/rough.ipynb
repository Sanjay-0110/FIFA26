# %%
# import requests
# import json
# from bs4 import BeautifulSoup

# def get_official_team_rating(url :str) -> dict:
#     headers = {
#                 "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36"
#         }
#     response = requests.get(url, headers=headers)
#     if response.status_code == 200 and response.text.strip():
#         data = response.text
#         soup = BeautifulSoup(data, "html.parser")

#         tables = soup.find_all('table')
#         for i, table in enumerate(tables):
#             print(f"Table {i}: {table.find('tr').get_text(strip=True)[:80]}")


# get_official_team_rating("https://inside.fifa.com/fifa-rankings/futsal-world-ranking/men")

import requests
import pandas as pd

def get_fifa_futsal_rankings(date_id="id15103men"):
    url = "https://inside.fifa.com/api/ranking-overview"
    
    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36",
        "Accept": "application/json",
        "Referer": "https://inside.fifa.com/fifa-rankings/futsal-world-ranking/men"
    }
    
    params = {
        "locale": "en",
        "dateId": date_id,
        "rankingType": "futsal"
    }
    
    response = requests.get(url, headers=headers, params=params)
    
    print("Status:", response.status_code)
    print("Content-Type:", response.headers.get("Content-Type"))
    
    data = response.json()
    print("Top-level keys:", data.keys())
    print(data)  # inspect raw structure first
    return data

data = get_fifa_futsal_rankings()
# print ("Data keys:", data.keys())
# Out:
# Status: 200
# Content-Type: application/json; charset=utf-8
# Top-level keys: dict_keys(['rankings'])
# {'rankings': [{'rankingItem': {'idTeam': '43924', 'rank': 1, 'flag': {'src': 'https://api.fifa.com/api/v3/picture/flags-sq-2/BRA', 'width': 70, 'height': 46, 'title': 'Brazil', 'alt': 'Brazil'}, 'name': 'Brazil', 'totalPoints': 1684.97, 'active': False, 'previousRank': 1, 'countryURL': '/fifa-world-ranking/BRA', 'countryCode': 'BRA'}, 'previousPoints': 1674.04, 'lastUpdateDate': '2026-05-08T08:50:00+00:00', 'nextUpdateDate': None, 'tag': {'id': 'CONMEBOL', 'text': 'CONMEBOL'}}, {'rankingItem': {'idTeam': '43963', 'rank': 2, 'flag': {'src': 'https://api.fifa.com/api/v3/picture/flags-sq-2/POR', 'width': 70, 'height': 46, 'title': 'Portugal', 'alt': 'Portugal'}, 'name': 'Portugal', 'totalPoints': 1575.32, 'active': False, 'previousRank': 2, 'countryURL': '/fifa-world-ranking/POR', 'countryCode': 'POR'}, 'previousPoints': 1536.17, 'lastUpdateDate': '2026-05-08T08:50:00+00:00', 'nextUpdateDate': None, 'tag': {'id': 'UEFA', 'text': 'UEFA'}}, {'rankingItem': {'idTeam': '43969', 'rank': 3, 'flag': {'src': 'https://api.fifa.com/api/v3/picture/flags-sq-2/ESP', 'width': 70, 'height': 46, 'title': 'Spain', 'alt': 'Spain'}, 'name': 'Spain', 'totalPoints': 1574.39, 'active': False, 'previousRank': 3, 'countryURL': '/fifa-world-ranking/ESP', 'countryCode': 'ESP'}, 'previousPoints': 1529.67, 'lastUpdateDate': '2026-05-08T08:50:00+00:00', 'nextUpdateDate': None, 'tag': {'id': 'UEFA', 'text': 'UEFA'}}, {'rankingItem': {'idTeam': '43922', 'rank': 4, 'flag': {'src': 'https://api.fifa.com/api/v3/picture/flags-sq-2/ARG', 'width': 70, 'height': 46, 'title': 'Argentina', 'alt': 'Argentina'}, 'name': 'Argentina', 'totalPoints': 1513.38, 'active': False, 'previousRank': 4, 'countryURL': '/fifa-world-ranking/ARG', 'countryCode': 'ARG'}, 'previousPoints': 1515.75, 'lastUpdateDate': '2026-05-08T08:50:00+00:00', 'nextUpdateDate': None, 'tag': {'id': 'CONMEBOL', 'text': 'CONMEBOL'}}, {'rankingItem': {'idTeam': '43817', 'rank': 5, 'flag': {'src': 'https://api.fifa.com/api/v3/picture/flags-sq-2/IRN', 'width': 70, 'height': 46, 'title': 'IR Iran', 'alt': 'IR Iran'}, 'name': 'IR Iran', 'totalPoints': 1507.71, 'active': False, 'previousRank': 5, 'countryURL': '/fifa-world-ranking/IRN', 'countryCode': 'IRN'}, 'previousPoints': 1484.23, 'lastUpdateDate': '2026-05-08T08:50:00+00:00', 'nextUpdateDate': None, 'tag': {'id': 'AFC', 'text': 'AFC'}}, {'rankingItem': {'idTeam': '43872', 'rank': 6, 'flag': {'src': 'https://api.fifa.com/api/v3/picture/flags-sq-2/MAR', 'width': 70, 'height': 46, 'title': 'Morocco', 'alt': 'Morocco'}, 'name': 'Morocco', 'totalPoints': 1486.53, 'active': False, 'previousRank': 6, 'countryURL': '/fifa-world-ranking/MAR', 'countryCode': 'MAR'}, 'previousPoints': 1481.26, 'lastUpdateDate': '2026-05-08T08:50:00+00:00', 'nextUpdateDate': None, 'tag': {'id': 'CAF', 'text': 'CAF'}}, {'rankingItem': {'idTeam': '43965', 'rank': 7, 'flag': {'src': 'https://api.fifa.com/api/v3/picture/flags-sq-2/RUS', 'width': 70, 'height': 46, 'title': 'Russia', 'alt': 'Russia'}, 'name': 'Russia', 'totalPoints': 1430.32, 'active': False, 'previousRank': 7, 'countryURL': '/fifa-world-ranking/RUS', 'countryCode': 'RUS'}, 'previousPoints': 1435.77, 'lastUpdateDate': '2026-05-08T08:50:00+00:00', 'nextUpdateDate': None, 'tag': {'id': 'UEFA', 'text': 'UEFA'}}, {'rankingItem': {'idTeam': '44027', 'rank': 8, 'flag': {'src': 'https://api.fifa.com/api/v3/picture/flags-sq-2/KAZ', 'width': 70, 'height': 46, 'title': 'Kazakhstan', 'alt': 'Kazakhstan'}, 'name': 'Kazakhstan', 'totalPoints': 1403.8, 'active': False, 'previousRank': 9, 'countryURL': '/fifa-world-ranking/KAZ', 'countryCode': 'KAZ'}, 'previousPoints': 1400.6, 'lastUpdateDate': '2026-05-08T08:50:00+00:00', 'nextUpdateDate': None, 'tag': {'id': 'UEFA', 'text': 'UEFA'}}, {'rankingItem': {'idTeam': '43973', 'rank': 9, 'flag': {'src': 'https://api.fifa.com/api/v3/picture/flags-sq-2/UKR', 'width': 70, 'height': 46, 'title': 'Ukraine', 'alt': 'Ukraine'}, 'name': 'Ukraine', 'totalPoints': 1400.89, 'active': False, 'previousRank': ...

# %%
data['rankings'][0]['rankingItem']
# Out:
# {'idTeam': '43924',
#  'rank': 1,
#  'flag': {'src': 'https://api.fifa.com/api/v3/picture/flags-sq-2/BRA',
#   'width': 70,
#   'height': 46,
#   'title': 'Brazil',
#   'alt': 'Brazil'},
#  'name': 'Brazil',
#  'totalPoints': 1684.97,
#  'active': False,
#  'previousRank': 1,
#  'countryURL': '/fifa-world-ranking/BRA',
#  'countryCode': 'BRA'}

# %%
len(data['rankings'])
# Out:
# 211

# %%
lst = []
for i in range(len(data['rankings'])):
    rank = data['rankings'][i]['rankingItem']['rank']
    team_name = data['rankings'][i]['rankingItem']['name']
    points = data['rankings'][i]['rankingItem']['totalPoints']
    previous_rank = data['rankings'][i]['rankingItem']['previousRank']
    country_code = data['rankings'][i]['rankingItem']['countryCode']
    lst.append((rank, team_name, points, previous_rank, country_code))

# %%
df = pd.DataFrame(lst, columns=['Rank', 'Team Name', 'Points', 'Previous Rank', 'Country Code'])
print(df.head())
# Out:
#    Rank  Team Name   Points  Previous Rank Country Code
# 0   1.0     Brazil  1684.97            1.0          BRA
# 1   2.0   Portugal  1575.32            2.0          POR
# 2   3.0      Spain  1574.39            3.0          ESP
# 3   4.0  Argentina  1513.38            4.0          ARG
# 4   5.0    IR Iran  1507.71            5.0          IRN
