# %% [markdown]
# # ⚽ Predict the FIFA World Cup 2026
#
# ## 📖 Background
#
# The 2026 FIFA World Cup is one of the biggest sporting events in the world, hosted across the United States, Canada, and Mexico. For the first time, the tournament expands to 48 teams, producing 104 matches across the group stage and knockout rounds.
#
# Using machine learning, historical statistics, and soccer domain knowledge, predict match scores, corners, and cards for every fixture. You must submit all your predictions before a single ball is kicked.
#
# The scoring system rewards precision: an exact scoreline earns maximum points, while close predictions still earn partial credit. Later rounds carry score multipliers, so a strong model that holds up in the knockout stages can leapfrog the competition. The challenge is designed to be difficult enough that no one can achieve a perfect score—even with AI assistance—but accessible enough that any data enthusiast can participate and score points.

# %% [markdown]
# ## 💾 The data
#
# You have access to the following files:
#
# #### `data/group_fixtures.csv` — all 72 group stage matches
# | Variable | Description |
# |---|---|
# | `match_id` | Unique match identifier |
# | `group` | Group letter (A–L) |
# | `home_team` | Home team name |
# | `away_team` | Away team name |
# | `date` | Match date (UTC) |
# | `venue` | Stadium and city |
#
# #### `data/knockout_slots.csv` — all 32 knockout round slots
# | Variable | Description |
# |---|---|
# | `match_id` | Unique match identifier |
# | `round` | Round name (e.g. `Quarter-final`) |
# | `multiplier` | Score multiplier for this round |
# | `slot_home` | Description of the home team slot (e.g. `Winner Group A`) |
# | `slot_away` | Description of the away team slot |
#
# | Variable | Description |
# |---|---|
#
# You may also bring in any external data—FIFA rankings, historical match results, player statistics—to build your predictions.

# %%
import pandas as pd


group_fixtures = pd.read_csv("C://Code Note//FIFA26//DataCamp Challenge//group_fixtures.csv")
group_fixtures.head()
# Out:
#    match_id group    home_team       away_team              date_utc  \
# 0         1     A       Mexico    South Africa  2026-06-11T19:00:00Z
# 1         2     A  South Korea  UEFA Playoff D  2026-06-12T02:00:00Z
# 2         3     B       Canada  UEFA Playoff A  2026-06-12T19:00:00Z
# 3         4     D          USA        Paraguay  2026-06-13T01:00:00Z
# 4         5     D    Australia  UEFA Playoff C  2026-06-13T04:00:00Z
#
#                          venue
# 0  Estadio Azteca, Mexico City
# 1   Estadio Akron, Guadalajara
# 2           BMO Field, Toronto
# 3    SoFi Stadium, Los Angeles
# 4          BC Place, Vancouver

# %%
knockout_slots = pd.read_csv("C://Code Note//FIFA26//DataCamp Challenge//knockout_slots.csv")
knockout_slots
# Out:
#     match_id                round  multiplier              date_utc  \
# 0         73          Round of 32           1  2026-06-28T19:00:00Z
# 1         74          Round of 32           1  2026-06-29T17:00:00Z
# 2         75          Round of 32           1  2026-06-29T20:30:00Z
# 3         76          Round of 32           1  2026-06-30T01:00:00Z
# 4         77          Round of 32           1  2026-06-30T17:00:00Z
# 5         78          Round of 32           1  2026-06-30T21:00:00Z
# 6         79          Round of 32           1  2026-07-01T01:00:00Z
# 7         80          Round of 32           1  2026-07-01T16:00:00Z
# 8         81          Round of 32           1  2026-07-01T20:00:00Z
# 9         82          Round of 32           1  2026-07-02T00:00:00Z
# 10        83          Round of 32           1  2026-07-02T19:00:00Z
# 11        84          Round of 32           1  2026-07-02T23:00:00Z
# 12        85          Round of 32           1  2026-07-03T03:00:00Z
# 13        86          Round of 32           1  2026-07-03T18:00:00Z
# 14        87          Round of 32           1  2026-07-03T22:00:00Z
# 15        88          Round of 32           1  2026-07-04T01:30:00Z
# 16        89          Round of 16           2  2026-07-04T17:00:00Z
# 17        90          Round of 16           2  2026-07-04T21:00:00Z
# 18        91          Round of 16           2  2026-07-05T20:00:00Z
# 19        92          Round of 16           2  2026-07-06T00:00:00Z
# 20        93          Round of 16           2  2026-07-06T19:00:00Z
# 21        94          Round of 16           2  2026-07-07T00:00:00Z
# 22        95          Round of 16           2  2026-07-07T16:00:00Z
# 23        96          Round of 16           2  2026-07-07T20:00:00Z
# 24        97        Quarter-final           4  2026-07-09T20:00:00Z
# 25        98        Quarter-final           4  2026-07-10T19:00:00Z
# 26        99        Quarter-final           4  2026-07-11T21:00:00Z
# 27       100        Quarter-final           4  2026-07-12T01:00:00Z
# 28       101           Semi-final           8  2026-07-14T19:00:00Z
# 29       102           Semi-final           8  2026-07-15T19:00:00Z
# 30       103  Third-place playoff           8  2026-07-18T21:00:00Z
# 31       104                Final          16  2026-07-19T19:00:00Z
#
#                                            venue          slot_home  \
# 0                      SoFi Stadium, Los Angeles  Runner-up Group A
# 1                           NRG Stadium, Houston     Winner Group C
# 2                       Gillette Stadium, Boston     Winner Group E
# 3                        Estadio BBVA, Monterrey     Winner Group F
# 4                           AT&T Stadium, Dallas  Runner-up Group E
# 5               MetLife Stadium, East Rutherford     Winner Group I
# 6                    Estadio Azteca, Mexico City     Winner Group A
# 7                 Mercedes-Benz Stadium, Atlanta     Winner Group L
# 8                           Lumen Field, Seattle     Winner Group G
# 9                    Levi's Stadium, Santa Clara     Winner Group D
# 10                            BMO Field, Toronto  Runner-up Group K
# 11                     SoFi Stadium, Los Angeles     Winner Group H
# 12                           BC Place, Vancouver     Winner Group B
# 13                          AT&T Stadium, Dallas  Runner-up Group D
# 14                      Hard Rock Stadium, Miami     Winner Group J
# 15  GEHA Field at Arrowhead Stadium, Kansas City     Winner Group K
# 16                          NRG Stadium, Houston    Winner Match 73
# 17         Lincoln Financial Field, Philadelphia    Winner Match 74
# 18              MetLife Stadium, East Rutherford    Winner Match 76
# 19                   Estadio Azteca, Mexico City    Winner Match 79
# 20                          AT&T Stadium, Dallas    Winner Match 83
# 21                          Lumen Field, Seattle    Winner Match 81
# 22                Mercedes-Benz Stadium, Atlanta    Winner Match 86
# 23                           BC Place, Vancouver    Winner Match 85
# 24                      Gillette Stadium, Boston    Winner Match 89
# 25                     SoFi Stadium, Los Angeles    Winner Match 93
# 26                      Hard Rock Stadium, Miami    Winner Match 91
# 27  GEHA Field at Arrowhead Stadium, Kansas City    Winner Match 95
# 28                          AT&T Stadium, Dallas    Winner Match 97
# 29                Mercedes-Benz Stadium, Atlanta    Winner Match 99
# 30                      Hard Rock Stadium, Miami    Loser Match 101
# 31              MetLife Stadium, East Rutherford   Winner Match 101
#
#                       slot_away
# 0             Runner-up Group B
# 1             Runner-up Group F
# 2   Best 3rd (Groups A/B/C/D/F)
# 3             Runner-up Group C
# 4             Runner-up Group I
# 5   Best 3rd (Groups C/D/F/G/H)
# 6   Best 3rd (Groups C/E/F/H/I)
# 7   Best 3rd (Groups E/H/I/J/K)
# 8   Best 3rd (Groups A/E/H/I/J)
# 9   Best 3rd (Groups B/E/F/I/J)
# 10            Runner-up Group L
# 11            Runner-up Group J
# 12  Best 3rd (Groups E/F/G/I/J)
# 13            Runner-up Group G
# 14            Runner-up Group H
# 15  Best 3rd (Groups D/E/I/J/L)
# 16              Winner Match 75
# 17              Winner Match 77
# 18              Winner Match 78
# 19              Winner Match 80
# 20              Winner Match 84
# 21              Winner Match 82
# 22              Winner Match 88
# 23              Winner Match 87
# 24              Winner Match 90
# 25              Winner Match 94
# 26              Winner Match 92
# 27              Winner Match 96
# 28              Winner Match 98
# 29             Winner Match 100
# 30              Loser Match 102
# 31             Winner Match 102

# %% [markdown]
# ## 💪 Competition challenge
#
# The 2026 World Cup has two phases:
#
# - **Group stage** (matches 1–72): The 48 teams are split into 12 groups of 4. Every team plays the other 3 teams in their group once. The best teams from each group advance to the next phase.
# - **Knockout stage** (matches 73–104): Single-elimination rounds — Round of 32, Round of 16, Quarter-finals, Semi-finals, and the Final. Lose once and you're out. Crucially, the two teams playing in each knockout match are not known in advance: they depend on who qualified from the group stage.
#
# Submit predictions for **every match** in both phases. For each match you need to predict:
#
# 1. **Score** — the exact final scoreline (e.g. `2-1` means the home team scores 2, the away team scores 1). For knockout matches, the score is the result after 90 minutes and extra time — the penalty shootout is not included.
# 2. **Corners** — the number of corner kicks awarded in the match
# 3. **Yellow cards** — the number of yellow cards shown in the match
# 4. **Red cards** — the number of red cards shown in the match
#
# For **group stage** matches, also predict:
# - **Winning team** — which team wins the individual match (use `home`, `away`, or `draw`)
#
# For **knockout round** matches, also predict:
# - **Matchup** — which two teams you predict will be playing in that slot. Because the bracket is determined by group stage results, you need to predict which teams advance far enough to meet in each round.
# - **Match winner** — which team wins the match (use `home` or `away`)
# - **Penalties** — whether the match goes to a penalty shootout (`True` or `False`)
#
# ### Scoring system
#
# | Category | Condition | Points |
# |---|---|---|
# | Score | Exact scoreline | 25 |
# | Score | Correct goal difference, wrong score | 10 |
# | Score | Correct total goals, wrong score | 10 |
# | Corners | Exact number | 10 |
# | Corners | Off by 2 | 5 |
# | Yellow cards | Exact number | 10 |
# | Yellow cards | Off by 1 | 5 |
# | Red cards | Exact number | 5 |
# | Winning team *(group stage only)* | Correct | 40 |
# | Matchup *(knockout only)* | Both teams correct | 20 |
# | Matchup *(knockout only)* | One team correct | 10 |
# | Match winner *(knockout only)* | Correct | 20 |
# | Penalties *(knockout only)* | Correct | 5 |
#
# All points for a match are multiplied by the round factor:
#
# | Round | Multiplier |
# |---|---|
# | Group stage | ×1 |
# | Round of 32 | ×1 |
# | Round of 16 | ×2 |
# | Quarter-final | ×4 |
# | Semi-final | ×8 |
# | Third-place playoff | ×8 |
# | Final | ×16 |

# %% [markdown]
# ## 🗓️ Group stage predictions
#
# Fill in your predictions for all 72 group stage matches below.

# %%
group_predictions = group_fixtures.copy()

# Fill in your predictions for each match
# Example (match 1 — Mexico vs South Africa): predicted_home_goals=2, predicted_away_goals=1, corners=9, yellow_cards=3, red_cards=0, winning_team='home'
group_predictions['predicted_home_goals'] = None   # e.g. 2
group_predictions['predicted_away_goals'] = None   # e.g. 1
group_predictions['corners']              = None   # e.g. 9
group_predictions['yellow_cards']         = None   # e.g. 3
group_predictions['red_cards']            = None   # e.g. 0
group_predictions['winning_team']         = None   # "home", "away", or "draw"

group_predictions
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 group_predictions = group_fixtures.copy()
#       3 # Fill in your predictions for each match
#       4 group_predictions['predicted_home_goals'] = None   # e.g. 2
#
# NameError: name 'group_fixtures' is not defined

# %% [markdown]
# ## 🏆 Knockout stage predictions
#
# For knockout matches you also predict **which teams are playing**. Fill in the team names based on your group stage predictions, then add your match predictions.

# %%
knockout_predictions = knockout_slots.copy()

# Fill in your predictions for each knockout match
# Example (match 73 — Round of 32): predicted_home_team='Brazil', predicted_away_team='France', predicted_home_goals=1, predicted_away_goals=0, corners=8, yellow_cards=2, red_cards=0, match_winner='home', penalties=False
knockout_predictions['predicted_home_team']  = None   # e.g. "Brazil"
knockout_predictions['predicted_away_team']  = None   # e.g. "France"
knockout_predictions['predicted_home_goals'] = None   # e.g. 1
knockout_predictions['predicted_away_goals'] = None   # e.g. 0
knockout_predictions['corners']              = None   # e.g. 8
knockout_predictions['yellow_cards']         = None   # e.g. 2
knockout_predictions['red_cards']            = None   # e.g. 0
knockout_predictions['match_winner']         = None   # "home" or "away"
knockout_predictions['penalties']            = None   # True or False

knockout_predictions

# %% [markdown]
# ## ✅ Checklist before publishing into the competition
#
# - Rename your workspace to make it descriptive of your work. N.B. you should leave the notebook name as `notebook.ipynb`.
# - Remove redundant cells like the judging criteria, so the workbook is focused on your predictions.
# - Make sure all prediction cells are filled in—`None` values will score 0 points.
# - Check that all cells run without error.
# - Make sure your workbook is published before **June 10, 2026 at 09:00 UTC**.

# %% [markdown]
# ## ⏳ Time is ticking. Good luck!

# %%
from math import exp, factorial
from itertools import product

# %%
HOME_ADVANTAGE   = 1.10   
MAX_GOALS        = 10    
ELO_SCALE        = 1800  
AVG_GOALS_TOTAL  = 2.55

# %%
group_fixtures.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72 entries, 0 to 71
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   match_id   72 non-null     int64
#  1   group      72 non-null     object
#  2   home_team  72 non-null     object
#  3   away_team  72 non-null     object
#  4   date_utc   72 non-null     object
#  5   venue      72 non-null     object
# dtypes: int64(1), object(5)
# memory usage: 3.5+ KB

# %%
group_fixtures.shape
# Out:
# (72, 6)

# %%
home_team =group_fixtures.home_team.unique()

# %%
away_team = group_fixtures.away_team.unique()

# %%
team = []
for i in range(len(home_team)):
    if home_team[i] not in team:
        team.append(home_team[i])
    elif away_team[i] not in team:
        team.append(away_team[i])

# %%
print(team)
# Out:
# ['Mexico', 'South Korea', 'Canada', 'USA', 'Australia', 'Qatar', 'Brazil', 'Haiti', 'Germany', 'Netherlands', "Côte d'Ivoire", 'UEFA Playoff B', 'Spain', 'Belgium', 'Saudi Arabia', 'Iran', 'Austria', 'France', 'FIFA Playoff 2', 'Argentina', 'Portugal', 'England', 'Ghana', 'Uzbekistan', 'UEFA Playoff D', 'Switzerland', 'UEFA Playoff C', 'Scotland', 'Tunisia', 'Ecuador', 'Uruguay', 'New Zealand', 'Norway', 'Jordan', 'Panama', 'Colombia', 'UEFA Playoff A', 'Morocco', 'South Africa', 'Curaçao', 'Japan', 'Paraguay', 'Senegal', 'Cabo Verde', 'Egypt', 'Croatia', 'FIFA Playoff 1', 'Algeria']

# %%
if 'Switzerland' in team:
    print("Switzerland is in the tournament!")
# Out:
# Switzerland is in the tournament!

# %%
group_fixtures[group_fixtures.home_team == 'FIFA Playoff 1']
# Out:
# Empty DataFrame
# Columns: [match_id, group, home_team, away_team, date_utc, venue]
# Index: []

# %% [markdown]
# UEFA Playoff B - Sweden
# UEFA Playoff A - Bosnia and Herzegovina
# FIFA Playoff 1 - Congo DR
# FIFA Playoff 2 - Iraq

# %% [markdown]
# ### Updating the team

# %%
group_fixtures.replace('UEFA Playoff B', 'Sweden', inplace=True)
group_fixtures.replace('UEFA Playoff A', 'Bosnia and Herzegovina', inplace=True)
group_fixtures.replace('UEFA Playoff D', 'Czech Republic', inplace=True)
group_fixtures.replace('UEFA Playoff C', 'Turkey', inplace=True)
group_fixtures.replace('FIFA Playoff 1', 'Congo DR', inplace=True)
group_fixtures.replace('FIFA Playoff 2', 'Iraq', inplace=True)
group_fixtures.replace("Côte d'Ivoire", "Ivory Coast", inplace=True)
group_fixtures.replace('Cabo Verde', 'Cape Verde', inplace=True)
group_fixtures.replace('Congo DR', 'DR Congo', inplace=True)

# %% [markdown]
# Now I have full team participating list updated.

# %%
TEAMS = {
    # ── GROUP A ──────────────────────────────────────────────
    "Mexico": {
        "elo": 1750, "attack": 1.6, "defense": 1.1,
        "confederation": "CONCACAF", "group": "A"
    },
    "South Africa": {
        "elo": 1480, "attack": 1.0, "defense": 1.4,
        "confederation": "CAF", "group": "A"
    },
    "South Korea": {
        "elo": 1620, "attack": 1.4, "defense": 1.1,
        "confederation": "AFC", "group": "A"
    },
    "Czech Republic": {
        "elo": 1590, "attack": 1.3, "defense": 1.2,
        "confederation": "UEFA", "group": "A"
    },
 
    # ── GROUP B ──────────────────────────────────────────────
    "Canada": {
        "elo": 1640, "attack": 1.5, "defense": 1.2,
        "confederation": "CONCACAF", "group": "B"
    },
    "Bosnia and Herzegovina": {
        "elo": 1540, "attack": 1.3, "defense": 1.3,
        "confederation": "UEFA", "group": "B"
    },
    "Qatar": {
        "elo": 1440, "attack": 0.9, "defense": 1.5,
        "confederation": "AFC", "group": "B"
    },
    "Switzerland": {
        "elo": 1720, "attack": 1.6, "defense": 1.0,
        "confederation": "UEFA", "group": "B"
    },
 
    # ── GROUP C ──────────────────────────────────────────────
     "Brazil": {
        "elo": 2050, "attack": 2.1, "defense": 0.8,
        "confederation": "CONMEBOL", "group": "C"
    },
    "Morocco": {
        "elo": 1730, "attack": 1.4, "defense": 0.8,
        "confederation": "CAF", "group": "C"
    },
    "Scotland": {
        "elo": 1640, "attack": 1.4, "defense": 1.2,
        "confederation": "UEFA", "group": "C"
    },
    "Haiti": {
    "elo": 1420, "attack": 0.9, "defense": 1.4,
    "confederation": "CONCACAF", "group": "C"
    },
 
    # ── GROUP D ──────────────────────────────────────────────
    "USA": {
        "elo": 1710, "attack": 1.5, "defense": 1.1,
        "confederation": "CONCACAF", "group": "D"
    },
    "Paraguay": {
        "elo": 1520, "attack": 1.1, "defense": 1.3,
        "confederation": "CONMEBOL", "group": "D"
    },
    "Australia": {
        "elo": 1590, "attack": 1.3, "defense": 1.2,
        "confederation": "AFC", "group": "D"
    },
    "Turkey": {
        "elo": 1650, "attack": 1.5, "defense": 1.2,
        "confederation": "UEFA", "group": "D"
    },
 
    # ── GROUP E ──────────────────────────────────────────────
    "Germany": {
        "elo": 1970, "attack": 2.0, "defense": 0.9,
        "confederation": "UEFA", "group": "E"
    },
    "Curaçao": {
        "elo": 1380, "attack": 0.8, "defense": 1.6,
        "confederation": "CONCACAF", "group": "E"
    },
    "Ecuador": {
        "elo": 1560, "attack": 1.2, "defense": 1.2,
        "confederation": "CONMEBOL", "group": "E"
    },
    "Ivory Coast": {
        "elo": 1620, "attack": 1.4, "defense": 1.2,
        "confederation": "CAF", "group": "E"
    },
 
    # ── GROUP F ──────────────────────────────────────────────
    "Netherlands": {
        "elo": 1920, "attack": 1.9, "defense": 0.9,
        "confederation": "UEFA", "group": "F"
    },
    "Japan": {
        "elo": 1760, "attack": 1.6, "defense": 0.9,
        "confederation": "AFC", "group": "F"
    },
    "Tunisia": {
        "elo": 1530, "attack": 1.2, "defense": 1.3,
        "confederation": "CAF", "group": "F"
    },
    "Sweden": {
        "elo": 1660, "attack": 1.5, "defense": 1.1,
        "confederation": "UEFA", "group": "F"
    },
 
    # ── GROUP G ──────────────────────────────────────────────
    "Belgium": {
        "elo": 1880, "attack": 1.9, "defense": 0.9,
        "confederation": "UEFA", "group": "G"
    },
    "Egypt": {
        "elo": 1600, "attack": 1.3, "defense": 1.2,
        "confederation": "CAF", "group": "G"
    },
    "Iran": {
        "elo": 1600, "attack": 1.2, "defense": 1.1,
        "confederation": "AFC", "group": "G"
    },
    "New Zealand": {
       "elo": 1380, "attack": 0.8, "defense": 1.3,
       "confederation": "OFC", "group": "G"
    },
 
    # ── GROUP H ──────────────────────────────────────────────
    "Spain": {
        "elo": 2100, "attack": 2.1, "defense": 0.7,
        "confederation": "UEFA", "group": "H"
    },
    "Cape Verde": {
        "elo": 1460, "attack": 1.0, "defense": 1.3,
        "confederation": "CAF", "group": "H"
    },
    "Uruguay": {
        "elo": 1780, "attack": 1.7, "defense": 0.9,
        "confederation": "CONMEBOL", "group": "H"
    },
    "Saudi Arabia": {
            "elo": 1565, "attack": 1.1, "defense": 1.2,
            "confederation": "AFC", "group": "H"
    },
 
    # ── GROUP I ──────────────────────────────────────────────
    "France": {
        "elo": 2060, "attack": 2.1, "defense": 0.8,
        "confederation": "UEFA", "group": "I"
    },
    "Senegal": {
        "elo": 1680, "attack": 1.4, "defense": 1.0,
        "confederation": "CAF", "group": "I"
    },
    "Iraq": {
        "elo": 1430, "attack": 1.0, "defense": 1.5,
        "confederation": "AFC", "group": "I"
    },
    
    "Norway": {
        "elo": 1700, "attack": 1.8, "defense": 1.1,
        "confederation": "UEFA", "group": "I"
    },
 
    # ── GROUP J ──────────────────────────────────────────────
    "Argentina": {
        "elo": 2080, "attack": 2.2, "defense": 0.8,
        "confederation": "CONMEBOL", "group": "J"
    },
    "Algeria": {
        "elo": 1560, "attack": 1.2, "defense": 1.3,
        "confederation": "CAF", "group": "J"
    },
    "Austria": {
        "elo": 1720, "attack": 1.7, "defense": 1.0,
        "confederation": "UEFA", "group": "J"
    },
    "Jordan": {
        "elo": 1420, "attack": 0.9, "defense": 1.5,
        "confederation": "AFC", "group": "J"
    },
 
    # ── GROUP K ──────────────────────────────────────────────
    "Portugal": {
        "elo": 1970, "attack": 2.0, "defense": 0.9,
        "confederation": "UEFA", "group": "K"
    },
    "DR Congo": {
        "elo": 1450, "attack": 1.0, "defense": 1.4,
        "confederation": "CAF", "group": "K"
    },
    "Colombia": {
        "elo": 1730, "attack": 1.7, "defense": 1.0,
        "confederation": "CONMEBOL", "group": "K"
    },
    "Uzbekistan": {
        "elo": 1410, "attack": 0.9, "defense": 1.5,
        "confederation": "AFC", "group": "K"
    },
 
    # ── GROUP L ──────────────────────────────────────────────
    "England": {
        "elo": 2030, "attack": 2.0, "defense": 0.8,
        "confederation": "UEFA", "group": "L"
    },
    "Croatia": {
        "elo": 1820, "attack": 1.7, "defense": 0.9,
        "confederation": "UEFA", "group": "L"
    },
    "Ghana": {
    "elo": 1510, "attack": 1.1, "defense": 1.3,
    "confederation": "CAF", "group": "L"
    },
    "Panama": {
    "elo": 1470, "attack": 1.0, "defense": 1.3,
    "confederation": "CONCACAF", "group": "L"
    }
    
}

# %%
def get_team(name: str) -> dict:

    if name not in TEAMS:
        raise ValueError(f"Team '{name}' not found in TEAMS dictionary.")
    
    return TEAMS[name]

def get_team_elo(name: str) -> int:
    team_info = get_team(name)
    return team_info['elo']

def get_team_group(name: str) -> str:
    team_info = get_team(name)
    return team_info['group']

def elo_lambda(elo_a: int, elo_b: int) -> float:

    diff = elo_b - elo_a
    return 10 ** (diff / ELO_SCALE)

# %%
f = get_team_group("France")
print(f)
# Out:
# I

# %%
def compute_lambda(home_team: str, away_team: str) -> float:
    elo_a = get_team_elo(home_team)
    elo_b = get_team_elo(away_team)
    a = get_team(home_team)
    b = get_team(away_team)
    base_lambda = AVG_GOALS_TOTAL / 2
    
    lambda_a = base_lambda * a['attack'] * a['defense'] * elo_lambda(elo_a, elo_b) * HOME_ADVANTAGE
    lambda_b = base_lambda * b['attack'] * b['defense'] * (1/ elo_lambda(elo_b, elo_a))

    return lambda_a, lambda_b

def poisson_dis(lam: float, k:int) -> float:
    if lam <= 0:
        return 0.0
    return (lam ** k * exp(-lam)) / factorial(k)

def score_line_matrix(lambda_a: float, lambda_b: float):
    matrix = {}
    for goal_a, goal_b in product(range(MAX_GOALS + 1), repeat=2):
        prob_a = poisson_dis(lambda_a, goal_a)
        prob_b = poisson_dis(lambda_b, goal_b)
        matrix[(goal_a, goal_b)] = prob_a * prob_b

    return matrix

def match_outcome_probabilities(home_team: str, away_team:str, neutral: bool = True) -> dict:

    group = get_team_group(home_team)
    lam_a, lam_b = compute_lambda(home_team, away_team)
    matrix = score_line_matrix(lam_a, lam_b)
    
    prob_home_win = sum(prob for (a, b), prob in matrix.items() if a > b)
    prob_away_win = sum(prob for (a, b), prob in matrix.items() if a < b)
    prob_draw     = sum(prob for (a, b), prob in matrix.items() if a == b)

    top = sorted(matrix.items(), key=lambda x: x[1], reverse=True)[:5]
    top_scorelines = [(f"{ga}-{gb}", round(p * 100, 2)) for (ga, gb), p in top]
    return {
        "home_team": home_team,
        "away_team": away_team,
        "Group": group,
        "home_win": prob_home_win*100,
        "away_win": prob_away_win*100,
        "draw": prob_draw*100,
        "top_scorelines": top_scorelines[0:3],
        "expected_total_goals": round(lam_a + lam_b, 2),
        "Probable team win": home_team if prob_home_win > prob_away_win else away_team if prob_away_win > prob_home_win else "Draw"
        
    }

# %%
team = []
for x, row in group_fixtures.iterrows():
    home = row['home_team']
    away = row['away_team']
    probs = match_outcome_probabilities(home, away, True)
    print(probs)
    team.append(probs)
    # # print(f"{home} vs {away}: {probs}")
# Out:
# {'home_team': 'Mexico', 'away_team': 'South Africa', 'Group': 'A', 'home_win': 48.77918430518601, 'away_win': 27.727735311679965, 'draw': 23.49283346255082, 'top_scorelines': [('1-1', 10.87), ('2-1', 9.5), ('1-0', 8.6)], 'expected_total_goals': 3.01, 'Probable team win': 'Mexico'}
# {'home_team': 'South Korea', 'away_team': 'Czech Republic', 'Group': 'A', 'home_win': 42.83974749548807, 'away_win': 36.49801034719543, 'draw': 20.66050589733746, 'top_scorelines': [('2-1', 7.63), ('1-1', 7.34), ('2-2', 7.3)], 'expected_total_goals': 3.99, 'Probable team win': 'South Korea'}
# {'home_team': 'Canada', 'away_team': 'Bosnia and Herzegovina', 'Group': 'B', 'home_win': 46.09387670815044, 'away_win': 33.75330334759354, 'draw': 20.15015379095642, 'top_scorelines': [('2-1', 7.62), ('2-2', 7.22), ('1-1', 6.86)], 'expected_total_goals': 4.12, 'Probable team win': 'Canada'}
# {'home_team': 'USA', 'away_team': 'Paraguay', 'Group': 'D', 'home_win': 46.72282213709653, 'away_win': 30.46793751704719, 'draw': 22.808868313496713, 'top_scorelines': [('1-1', 10.12), ('2-1', 9.18), ('1-2', 7.23)], 'expected_total_goals': 3.24, 'Probable team win': 'USA'}
# {'home_team': 'Australia', 'away_team': 'Turkey', 'Group': 'D', 'home_win': 38.630929029421026, 'away_win': 42.70809932482963, 'draw': 18.651524124047754, 'top_scorelines': [('2-2', 6.77), ('1-2', 5.73), ('2-3', 5.59)], 'expected_total_goals': 4.84, 'Probable team win': 'Turkey'}
# {'home_team': 'Qatar', 'away_team': 'Switzerland', 'Group': 'B', 'home_win': 37.95628202774742, 'away_win': 44.83098767899034, 'draw': 17.177144986138877, 'top_scorelines': [('2-2', 5.62), ('2-3', 5.47), ('3-2', 5.08)], 'expected_total_goals': 5.63, 'Probable team win': 'Switzerland'}
# {'home_team': 'Brazil', 'away_team': 'Morocco', 'Group': 'C', 'home_win': 51.72124831634268, 'away_win': 22.88638191407559, 'draw': 25.392286381226608, 'top_scorelines': [('1-0', 12.68), ('1-1', 12.02), ('2-0', 9.92)], 'expected_total_goals': 2.51, 'Probable team win': 'Brazil'}
# {'home_team': 'Haiti', 'away_team': 'Scotland', 'Group': 'C', 'home_win': 32.74853215150563, 'away_win': 49.598898915143046, 'draw': 17.63074704792898, 'top_scorelines': [('2-2', 6.22), ('2-3', 5.88), ('1-2', 5.31)], 'expected_total_goals': 5.18, 'Probable team win': 'Scotland'}
# {'home_team': 'Germany', 'away_team': 'Curaçao', 'Group': 'E', 'home_win': 45.83536290326489, 'away_win': 23.840871891691627, 'draw': 30.32375955793627, 'top_scorelines': [('1-0', 16.82), ('0-0', 14.17), ('1-1', 12.9)], 'expected_total_goals': 1.95, 'Probable team win': 'Germany'}
# {'home_team': 'Netherlands', 'away_team': 'Japan', 'Group': 'F', 'home_win': 48.44325876492944, 'away_win': 29.666168159652027, 'draw': 21.889847519729734, 'top_scorelines': [('1-1', 9.28), ('2-1', 9.07), ('1-2', 6.94)], 'expected_total_goals': 3.45, 'Probable team win': 'Netherlands'}
# {'home_team': 'Ivory Coast', 'away_team': 'Ecuador', 'Group': 'E', 'home_win': 49.0954320933907, 'away_win': 30.3968711327631, 'draw': 20.50567560864307, 'top_scorelines': [('2-1', 8.34), ('1-1', 7.64), ('2-2', 7.09)], 'expected_total_goals': 3.88, 'Probable team win': 'Ivory Coast'}
# {'home_team': 'Sweden', 'away_team': 'Tunisia', 'Group': 'F', 'home_win': 44.730215701890295, 'away_win': 33.67239648998705, 'draw': 21.59653238935401, 'top_scorelines': [('1-1', 8.63), ('2-1', 8.46), ('1-2', 7.27)], 'expected_total_goals': 3.64, 'Probable team win': 'Sweden'}
# {'home_team': 'Spain', 'away_team': 'Cape Verde', 'Group': 'H', 'home_win': 37.74834843761178, 'away_win': 27.660893865037607, 'draw': 34.5907572733986, 'top_scorelines': [('0-0', 19.39), ('1-0', 17.63), ('0-1', 14.18)], 'expected_total_goals': 1.64, 'Probable team win': 'Spain'}
# {'home_team': 'Belgium', 'away_team': 'Egypt', 'Group': 'G', 'home_win': 44.34018335328796, 'away_win': 31.92064926390545, 'draw': 23.73898132912951, 'top_scorelines': [('1-1', 10.86), ('2-1', 9.1), ('1-0', 7.81)], 'expected_total_goals': 3.07, 'Probable team win': 'Belgium'}
# {'home_team': 'Saudi Arabia', 'away_team': 'Uruguay', 'Group': 'H', 'home_win': 38.56481721420613, 'away_win': 43.10750908324623, 'draw': 18.31494607860204, 'top_scorelines': [('2-2', 6.56), ('2-3', 5.62), ('1-2', 5.39)], 'expected_total_goals': 5.01, 'Probable team win': 'Uruguay'}
# {'home_team': 'Iran', 'away_team': 'New Zealand', 'Group': 'G', 'home_win': 46.053054938655045, 'away_win': 26.94841162553604, 'draw': 26.998504686712465, 'top_scorelines': [('1-1', 12.71), ('1-0', 12.7), ('0-1', 9.1)], 'expected_total_goals': 2.4, 'Probable team win': 'Iran'}
# {'home_team': 'Austria', 'away_team': 'Jordan', 'Group': 'J', 'home_win': 47.877731656125924, 'away_win': 27.551298752401664, 'draw': 24.570846250546328, 'top_scorelines': [('1-1', 11.62), ('1-0', 9.91), ('2-1', 9.44)], 'expected_total_goals': 2.8, 'Probable team win': 'Austria'}
# {'home_team': 'France', 'away_team': 'Senegal', 'Group': 'I', 'home_win': 45.15240697737604, 'away_win': 28.631093355829535, 'draw': 26.21645757326806, 'top_scorelines': [('1-1', 12.46), ('1-0', 11.35), ('2-1', 9.03)], 'expected_total_goals': 2.55, 'Probable team win': 'France'}
# {'home_team': 'Iraq', 'away_team': 'Norway', 'Group': 'I', 'home_win': 33.18205884654113, 'away_win': 51.13240313803568, 'draw': 15.540524879516735, 'top_scorelines': [('2-3', 4.83), ('3-3', 4.79), ('2-4', 4.31)], 'expected_total_goals': 6.54, 'Probable team win': 'Norway'}
# {'home_team': 'Argentina', 'away_team': 'Algeria', 'Group': 'J', 'home_win': 42.00542095896459, 'away_win': 29.843646752858426, 'draw': 28.150920200765384, 'top_scorelines': [('1-1', 13.12), ('1-0', 12.83), ('0-1', 10.34)], 'expected_total_goals': 2.29, 'Probable team win': 'Argentina'}
# {'home_team': 'Portugal', 'away_team': 'DR Congo', 'Group': 'K', 'home_win': 45.31703581469438, 'away_win': 26.36169671728956, 'draw': 28.321253541024017, 'top_scorelines': [('1-0', 14.16), ('1-1', 12.99), ('0-0', 10.91)], 'expected_total_goals': 2.22, 'Probable team win': 'Portugal'}
# {'home_team': 'England', 'away_team': 'Croatia', 'Group': 'L', 'home_win': 43.150605745654715, 'away_win': 33.60006463225936, 'draw': 23.24907892890695, 'top_scorelines': [('1-1', 10.36), ('2-1', 8.88), ('1-2', 7.72)], 'expected_total_goals': 3.21, 'Probable team win': 'England'}
# {'home_team': 'Ghana', 'away_team': 'Panama', 'Group': 'L', 'home_win': 45.74540946734788, 'away_win': 32.19743666971369, 'draw': 22.056534374687626, 'top_scorelines': [('1-1', 9.24), ('2-1', 8.81), ('1-2', 7.28)], 'expected_total_goals': 3.48, 'Probable team win': 'Ghana'}
# {'home_team': 'Uzbekistan', 'away_team': 'Colombia', 'Group': 'K', 'home_win': 35.34216796835302, 'away_win': 48.28915200673656, 'draw': 16.291241354729014, 'top_scorelines': [('2-3', 5.2), ('3-3', 4.95), ('2-2', 4.78)], 'expected_total_goals': 6.12, 'Probable team win': 'Colombia'}
# {'home_team': 'Czech Republic', 'away_team': 'South Africa', 'Group': 'A', 'home_win': 46.131940281456316, 'away_win': 31.74548724749988, 'draw': 22.12197744158433, 'top_scorelines': [('1-1', 9.34), ('2-1', 8.88), ('1-2', 7.24)], 'expected_total_goals': 3.45, 'Probable team win': 'Czech Republic'}
# {'home_team': 'Switzerland', 'away_team': 'Bosnia and Herzegovina', 'Group': 'B', 'home_win': 40.310702293298434, 'away_win': 37.40096688114149, 'draw': 22.28785136252461, 'top_scorelines': [('1-1', 9.27), ('2-1', 8.26), ('1-2', 7.93)], 'expected_total_goals': 3.49, 'Probable team win': 'Switzerland'}
# {'home_team': 'Canada', 'away_team': 'Qatar', 'Group': 'B', 'home_win': 51.9553730259818, 'away_win': 26.075350702558055, 'draw': 21.96858628856088, 'top_scorelines': [('1-1', 9.73), ('2-1', 9.51), ('1-0', 7.3)], 'expected_total_goals': 3.29, 'Probable team win': 'Canada'}
# {'home_team': 'Mexico', 'away_team': 'South Korea', 'Group': 'A', 'home_win': 47.94254168365067, 'away_win': 31.0615317317602, 'draw': 20.99453452825579, 'top_scorelines': [('2-1', 8.52), ('1-1', 8.15), ('2-2', 7.08)], 'expected_total_goals': 3.75, 'Probable team win': 'Mexico'}
# {'home_team': 'Turkey', 'away_team': 'Paraguay', 'Group': 'D', 'home_win': 51.359378806363154, 'away_win': 27.843356376859862, 'draw': 20.795665624032672, 'top_scorelines': [('2-1', 8.88), ('1-1', 8.31), ('2-2', 6.86)], 'expected_total_goals': 3.68, 'Probable team win': 'Turkey'}
# {'home_team': 'USA', 'away_team': 'Australia', 'Group': 'D', 'home_win': 44.84576254832722, 'away_win': 33.71173527231547, 'draw': 21.441539109223033, 'top_scorelines': [('1-1', 8.45), ('2-1', 8.38), ('1-2', 7.21)], 'expected_total_goals': 3.69, 'Probable team win': 'USA'}
# {'home_team': 'Scotland', 'away_team': 'Morocco', 'Group': 'C', 'home_win': 59.94363295032768, 'away_win': 22.14578614299189, 'draw': 17.9004617423651, 'top_scorelines': [('2-1', 8.02), ('3-1', 7.07), ('2-2', 6.42)], 'expected_total_goals': 4.25, 'Probable team win': 'Scotland'}
# {'home_team': 'Brazil', 'away_team': 'Haiti', 'Group': 'C', 'home_win': 42.890754383241934, 'away_win': 24.571125065840274, 'draw': 32.5381188357958, 'top_scorelines': [('1-0', 17.93), ('0-0', 17.03), ('1-1', 12.86)], 'expected_total_goals': 1.77, 'Probable team win': 'Brazil'}
# {'home_team': 'Tunisia', 'away_team': 'Japan', 'Group': 'F', 'home_win': 49.19716302225767, 'away_win': 33.48065019196326, 'draw': 17.292316230303893, 'top_scorelines': [('2-2', 5.91), ('3-2', 5.78), ('2-3', 4.85)], 'expected_total_goals': 5.4, 'Probable team win': 'Tunisia'}
# {'home_team': 'Netherlands', 'away_team': 'Sweden', 'Group': 'F', 'home_win': 42.89677225788959, 'away_win': 33.924405506651254, 'draw': 23.178560604446922, 'top_scorelines': [('1-1', 10.28), ('2-1', 8.84), ('1-2', 7.75)], 'expected_total_goals': 3.23, 'Probable team win': 'Netherlands'}
# {'home_team': 'Germany', 'away_team': 'Ivory Coast', 'Group': 'E', 'home_win': 43.28465081223157, 'away_win': 32.529861908223, 'draw': 24.185353597874922, 'top_scorelines': [('1-1', 11.19), ('2-1', 9.03), ('1-0', 8.18)], 'expected_total_goals': 2.98, 'Probable team win': 'Germany'}
# {'home_team': 'Ecuador', 'away_team': 'Curaçao', 'Group': 'E', 'home_win': 44.622641111997694, 'away_win': 30.927765167665157, 'draw': 24.449475282172795, 'top_scorelines': [('1-1', 11.44), ('2-1', 9.17), ('1-0', 8.82)], 'expected_total_goals': 2.9, 'Probable team win': 'Ecuador'}
# {'home_team': 'Spain', 'away_team': 'Saudi Arabia', 'Group': 'H', 'home_win': 39.24601720769348, 'away_win': 29.024447734784957, 'draw': 31.729533376993945, 'top_scorelines': [('1-0', 15.73), ('0-0', 15.12), ('1-1', 13.35)], 'expected_total_goals': 1.89, 'Probable team win': 'Spain'}
# {'home_team': 'Belgium', 'away_team': 'Iran', 'Group': 'G', 'home_win': 49.05819894380728, 'away_win': 26.794922859509978, 'draw': 24.146713452206633, 'top_scorelines': [('1-1', 11.38), ('1-0', 9.67), ('2-1', 9.53)], 'expected_total_goals': 2.85, 'Probable team win': 'Belgium'}
# {'home_team': 'Uruguay', 'away_team': 'Cape Verde', 'Group': 'H', 'home_win': 44.451040908158355, 'away_win': 29.132839499089524, 'draw': 26.416083363458288, 'top_scorelines': [('1-1', 12.55), ('1-0', 11.4), ('2-1', 8.94)], 'expected_total_goals': 2.53, 'Probable team win': 'Uruguay'}
# {'home_team': 'New Zealand', 'away_team': 'Egypt', 'Group': 'G', 'home_win': 28.257716995189984, 'away_win': 53.37022500789208, 'draw': 18.361702991772237, 'top_scorelines': [('1-2', 6.97), ('2-2', 6.73), ('1-3', 6.12)], 'expected_total_goals': 4.57, 'Probable team win': 'Egypt'}
# {'home_team': 'Argentina', 'away_team': 'Austria', 'Group': 'J', 'home_win': 41.9506073911338, 'away_win': 33.51748090615907, 'draw': 24.53180999508402, 'top_scorelines': [('1-1', 11.43), ('2-1', 8.9), ('1-0', 8.36)], 'expected_total_goals': 2.93, 'Probable team win': 'Argentina'}
# {'home_team': 'France', 'away_team': 'Iraq', 'Group': 'I', 'home_win': 39.515545104379626, 'away_win': 28.951170915590417, 'draw': 31.533282095754917, 'top_scorelines': [('1-0', 15.64), ('0-0', 14.86), ('1-1', 13.36)], 'expected_total_goals': 1.91, 'Probable team win': 'France'}
# {'home_team': 'Norway', 'away_team': 'Senegal', 'Group': 'I', 'home_win': 58.356570873898804, 'away_win': 23.827444383531734, 'draw': 17.80349056046931, 'top_scorelines': [('2-1', 7.47), ('3-1', 6.74), ('2-2', 6.5)], 'expected_total_goals': 4.45, 'Probable team win': 'Norway'}
# {'home_team': 'Jordan', 'away_team': 'Algeria', 'Group': 'J', 'home_win': 38.405268645660776, 'away_win': 42.51782958158089, 'draw': 19.070350754471722, 'top_scorelines': [('2-2', 6.98), ('1-2', 6.17), ('2-1', 5.87)], 'expected_total_goals': 4.64, 'Probable team win': 'Algeria'}
# {'home_team': 'Portugal', 'away_team': 'Uzbekistan', 'Group': 'K', 'home_win': 45.35258686336433, 'away_win': 25.255437710119306, 'draw': 29.391967095299375, 'top_scorelines': [('1-0', 15.5), ('1-1', 13.03), ('0-0', 12.57)], 'expected_total_goals': 2.07, 'Probable team win': 'Portugal'}
# {'home_team': 'England', 'away_team': 'Ghana', 'Group': 'L', 'home_win': 40.65326843198538, 'away_win': 29.554050498620466, 'draw': 29.792676331941177, 'top_scorelines': [('1-0', 14.25), ('1-1', 13.36), ('0-0', 12.35)], 'expected_total_goals': 2.09, 'Probable team win': 'England'}
# {'home_team': 'Panama', 'away_team': 'Croatia', 'Group': 'L', 'home_win': 38.40332584264347, 'away_win': 44.78953753930332, 'draw': 16.754207475230615, 'top_scorelines': [('2-3', 5.26), ('2-2', 5.17), ('3-3', 5.0)], 'expected_total_goals': 5.91, 'Probable team win': 'Croatia'}
# {'home_team': 'Colombia', 'away_team': 'DR Congo', 'Group': 'K', 'home_win': 47.209192156125106, 'away_win': 28.6762746453605, 'draw': 24.11437305623556, 'top_scorelines': [('1-1', 11.28), ('2-1', 9.4), ('1-0', 9.04)], 'expected_total_goals': 2.91, 'Probable team win': 'Colombia'}
# {'home_team': 'Switzerland', 'away_team': 'Canada', 'Group': 'B', 'home_win': 38.908136358662254, 'away_win': 40.66404759849343, 'draw': 20.425734316070894, 'top_scorelines': [('2-2', 7.32), ('1-2', 7.22), ('2-1', 7.06)], 'expected_total_goals': 4.1, 'Probable team win': 'Canada'}
# {'home_team': 'Bosnia and Herzegovina', 'away_team': 'Qatar', 'Group': 'B', 'home_win': 50.87902024513211, 'away_win': 28.014410093485324, 'draw': 21.105289621082388, 'top_scorelines': [('2-1', 9.0), ('1-1', 8.63), ('2-2', 6.81)], 'expected_total_goals': 3.6, 'Probable team win': 'Bosnia and Herzegovina'}
# {'home_team': 'Scotland', 'away_team': 'Brazil', 'Group': 'C', 'home_win': 47.55606069591597, 'away_win': 37.42596984763637, 'draw': 14.611810110118789, 'top_scorelines': [('3-3', 4.16), ('4-3', 4.14), ('3-4', 3.76)], 'expected_total_goals': 7.6, 'Probable team win': 'Scotland'}
# {'home_team': 'Morocco', 'away_team': 'Haiti', 'Group': 'C', 'home_win': 34.56853447531202, 'away_win': 35.79212324917604, 'draw': 29.639338337227635, 'top_scorelines': [('1-1', 13.47), ('0-1', 12.75), ('1-0', 12.47)], 'expected_total_goals': 2.14, 'Probable team win': 'Haiti'}
# {'home_team': 'Czech Republic', 'away_team': 'Mexico', 'Group': 'A', 'home_win': 40.06638771257614, 'away_win': 42.362395212977304, 'draw': 17.54557405302411, 'top_scorelines': [('2-2', 5.94), ('2-3', 5.45), ('3-2', 5.31)], 'expected_total_goals': 5.44, 'Probable team win': 'Mexico'}
# {'home_team': 'South Africa', 'away_team': 'South Korea', 'Group': 'A', 'home_win': 40.50774054677312, 'away_win': 40.50774054677309, 'draw': 18.977414426630073, 'top_scorelines': [('2-2', 6.94), ('2-1', 5.91), ('1-2', 5.91)], 'expected_total_goals': 4.7, 'Probable team win': 'South Africa'}
# {'home_team': 'Curaçao', 'away_team': 'Ivory Coast', 'Group': 'E', 'home_win': 33.42133108909537, 'away_win': 49.1774250880344, 'draw': 17.3734794347663, 'top_scorelines': [('2-2', 5.98), ('2-3', 5.8), ('1-2', 4.9)], 'expected_total_goals': 5.35, 'Probable team win': 'Ivory Coast'}
# {'home_team': 'Ecuador', 'away_team': 'Germany', 'Group': 'E', 'home_win': 35.768606762612265, 'away_win': 49.07741903397505, 'draw': 14.845912492458751, 'top_scorelines': [('3-3', 4.39), ('3-4', 4.26), ('2-3', 3.86)], 'expected_total_goals': 7.29, 'Probable team win': 'Germany'}
# {'home_team': 'Japan', 'away_team': 'Sweden', 'Group': 'F', 'home_win': 37.593125836782484, 'away_win': 40.58017554746042, 'draw': 21.826015670560757, 'top_scorelines': [('1-1', 8.74), ('1-2', 8.09), ('2-1', 7.76)], 'expected_total_goals': 3.63, 'Probable team win': 'Sweden'}
# {'home_team': 'Tunisia', 'away_team': 'Netherlands', 'Group': 'F', 'home_win': 42.47796481964918, 'away_win': 42.11332723114419, 'draw': 15.156264770180531, 'top_scorelines': [('3-3', 4.52), ('4-3', 4.07), ('3-4', 4.06)], 'expected_total_goals': 7.19, 'Probable team win': 'Tunisia'}
# {'home_team': 'USA', 'away_team': 'Turkey', 'Group': 'D', 'home_win': 40.33948147811575, 'away_win': 39.67668473172049, 'draw': 19.98082342601978, 'top_scorelines': [('2-2', 7.26), ('2-1', 6.83), ('1-2', 6.78)], 'expected_total_goals': 4.27, 'Probable team win': 'USA'}
# {'home_team': 'Paraguay', 'away_team': 'Australia', 'Group': 'D', 'home_win': 40.46782811279474, 'away_win': 39.79680388890386, 'draw': 19.73165428716589, 'top_scorelines': [('2-2', 7.21), ('2-1', 6.63), ('1-2', 6.57)], 'expected_total_goals': 4.37, 'Probable team win': 'Paraguay'}
# {'home_team': 'Norway', 'away_team': 'France', 'Group': 'I', 'home_win': 56.46896172537124, 'away_win': 29.203631499979704, 'draw': 13.67791963970265, 'top_scorelines': [('4-3', 4.19), ('3-3', 3.81), ('4-2', 3.71)], 'expected_total_goals': 7.8, 'Probable team win': 'Norway'}
# {'home_team': 'Senegal', 'away_team': 'Iraq', 'Group': 'I', 'home_win': 38.239212460961966, 'away_win': 36.56334837341453, 'draw': 25.197379125094727, 'top_scorelines': [('1-1', 11.87), ('1-0', 8.54), ('2-1', 8.46)], 'expected_total_goals': 2.82, 'Probable team win': 'Senegal'}
# {'home_team': 'Cape Verde', 'away_team': 'Saudi Arabia', 'Group': 'H', 'home_win': 42.77955327915357, 'away_win': 36.60470471106021, 'draw': 20.613940177804206, 'top_scorelines': [('2-1', 7.59), ('2-2', 7.3), ('1-1', 7.28)], 'expected_total_goals': 4.01, 'Probable team win': 'Cape Verde'}
# {'home_team': 'Uruguay', 'away_team': 'Spain', 'Group': 'H', 'home_win': 48.220333172654826, 'away_win': 35.328461343444516, 'draw': 16.379897830316313, 'top_scorelines': [('3-2', 5.26), ('3-3', 4.95), ('2-2', 4.88)], 'expected_total_goals': 6.05, 'Probable team win': 'Uruguay'}
# {'home_team': 'Egypt', 'away_team': 'Iran', 'Group': 'G', 'home_win': 49.5603839632865, 'away_win': 29.9518541754537, 'draw': 20.48571317730667, 'top_scorelines': [('2-1', 8.39), ('1-1', 7.67), ('2-2', 7.06)], 'expected_total_goals': 3.87, 'Probable team win': 'Egypt'}
# {'home_team': 'New Zealand', 'away_team': 'Belgium', 'Group': 'G', 'home_win': 23.538402626770043, 'away_win': 62.43497349827211, 'draw': 13.65011417576718, 'top_scorelines': [('2-4', 4.69), ('2-3', 4.54), ('3-4', 4.33)], 'expected_total_goals': 6.9, 'Probable team win': 'Belgium'}
# {'home_team': 'Panama', 'away_team': 'England', 'Group': 'L', 'home_win': 36.5314742704076, 'away_win': 48.648902094700496, 'draw': 14.262148062493823, 'top_scorelines': [('3-4', 4.04), ('3-3', 3.87), ('4-4', 3.77)], 'expected_total_goals': 7.91, 'Probable team win': 'England'}
# {'home_team': 'Croatia', 'away_team': 'Ghana', 'Group': 'L', 'home_win': 42.11044228335212, 'away_win': 32.08071236595075, 'draw': 25.808799600434483, 'top_scorelines': [('1-1', 12.26), ('1-0', 10.0), ('2-1', 8.85)], 'expected_total_goals': 2.67, 'Probable team win': 'Croatia'}
# {'home_team': 'Colombia', 'away_team': 'Portugal', 'Group': 'K', 'home_win': 43.75161825456324, 'away_win': 40.00732585127882, 'draw': 16.145546448400204, 'top_scorelines': [('3-3', 4.96), ('3-2', 4.77), ('2-3', 4.59)], 'expected_total_goals': 6.36, 'Probable team win': 'Colombia'}
# {'home_team': 'DR Congo', 'away_team': 'Uzbekistan', 'Group': 'K', 'home_win': 43.64320903200679, 'away_win': 34.22078735232651, 'draw': 22.13544098947296, 'top_scorelines': [('1-1', 9.2), ('2-1', 8.59), ('1-2', 7.53)], 'expected_total_goals': 3.5, 'Probable team win': 'DR Congo'}
# {'home_team': 'Algeria', 'away_team': 'Austria', 'Group': 'J', 'home_win': 41.552925374683504, 'away_win': 40.71087499158026, 'draw': 17.71420927932935, 'top_scorelines': [('2-2', 6.09), ('3-2', 5.45), ('2-3', 5.4)], 'expected_total_goals': 5.34, 'Probable team win': 'Algeria'}
# {'home_team': 'Jordan', 'away_team': 'Argentina', 'Group': 'J', 'home_win': 32.88299465576333, 'away_win': 52.127314480337006, 'draw': 12.612288546939762, 'top_scorelines': [('4-5', 3.35), ('4-4', 3.21), ('3-5', 3.04)], 'expected_total_goals': 9.62, 'Probable team win': 'Argentina'}

# %%
df = pd.DataFrame(team)
df.head()
# Out:
#      home_team               away_team Group   home_win   away_win       draw  \
# 0       Mexico            South Africa     A  48.779184  27.727735  23.492833
# 1  South Korea          Czech Republic     A  42.839747  36.498010  20.660506
# 2       Canada  Bosnia and Herzegovina     B  46.093877  33.753303  20.150154
# 3          USA                Paraguay     D  46.722822  30.467938  22.808868
# 4    Australia                  Turkey     D  38.630929  42.708099  18.651524
#
#                              top_scorelines  expected_total_goals  \
# 0    [(1-1, 10.87), (2-1, 9.5), (1-0, 8.6)]                  3.01
# 1    [(2-1, 7.63), (1-1, 7.34), (2-2, 7.3)]                  3.99
# 2   [(2-1, 7.62), (2-2, 7.22), (1-1, 6.86)]                  4.12
# 3  [(1-1, 10.12), (2-1, 9.18), (1-2, 7.23)]                  3.24
# 4   [(2-2, 6.77), (1-2, 5.73), (2-3, 5.59)]                  4.84
#
#   Probable team win
# 0            Mexico
# 1       South Korea
# 2            Canada
# 3               USA
# 4            Turkey

# %%
df.groupby('Group').apply(lambda x: x.sort_index())
# Out:
# C:\Users\sanja\AppData\Local\Temp\ipykernel_10304\1237485375.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df.groupby('Group').apply(lambda x: x.sort_index())
#                home_team       away_team Group   home_win   away_win  \
# Group
# A     0           Mexico    South Africa     A  48.779184  27.727735
#       1      South Korea  Czech Republic     A  42.839747  36.498010
#       24  Czech Republic    South Africa     A  46.131940  31.745487
#       27          Mexico     South Korea     A  47.942542  31.061532
#       52  Czech Republic          Mexico     A  40.066388  42.362395
# ...                  ...             ...   ...        ...        ...
# L     22           Ghana          Panama     L  45.745409  32.197437
#       45         England           Ghana     L  40.653268  29.554050
#       46          Panama         Croatia     L  38.403326  44.789538
#       66          Panama         England     L  36.531474  48.648902
#       67         Croatia           Ghana     L  42.110442  32.080712
#
#                draw                              top_scorelines  \
# Group
# A     0   23.492833      [(1-1, 10.87), (2-1, 9.5), (1-0, 8.6)]
#       1   20.660506      [(2-1, 7.63), (1-1, 7.34), (2-2, 7.3)]
#       24  22.121977     [(1-1, 9.34), (2-1, 8.88), (1-2, 7.24)]
#       27  20.994535     [(2-1, 8.52), (1-1, 8.15), (2-2, 7.08)]
#       52  17.545574     [(2-2, 5.94), (2-3, 5.45), (3-2, 5.31)]
# ...             ...                                         ...
# L     22  22.056534     [(1-1, 9.24), (2-1, 8.81), (1-2, 7.28)]
#       45  29.792676  [(1-0, 14.25), (1-1, 13.36), (0-0, 12.35)]
#       46  16.754207      [(2-3, 5.26), (2-2, 5.17), (3-3, 5.0)]
#       66  14.262148     [(3-4, 4.04), (3-3, 3.87), (4-4, 3.77)]
#       67  25.808800    [(1-1, 12.26), (1-0, 10.0), (2-1, 8.85)]
#
#           expected_total_goals Probable team win
# Group
# A     0                   3.01            Mexico
#       1                   3.99       South Korea
#       24                  3.45    Czech Republic
#       27                  3.75            Mexico
#       52                  5.44            Mexico
# ...                        ...               ...
# L     22                  3.48             Ghana
#       45                  2.09           England
#       46                  5.91           Croatia
#       66                  7.91           England
#       67                  2.67           Croatia
#
# [72 rows x 9 columns]

# %%
rows = []

for _, row in df.iterrows():
    group = row["Group"]

    if row["home_win"] > row["away_win"]:        # home wins
        rows.append({"team": row["home_team"], "group": group, "W":1, "D":0, "L":0, "pts":3})
        rows.append({"team": row["away_team"], "group": group, "W":0, "D":0, "L":1, "pts":0})

    elif row["away_win"] > row["home_win"]:       # away wins
        rows.append({"team": row["home_team"], "group": group, "W":0, "D":0, "L":1, "pts":0})
        rows.append({"team": row["away_team"], "group": group, "W":1, "D":0, "L":0, "pts":3})

    else:                                          # draw
        rows.append({"team": row["home_team"], "group": group, "W":0, "D":1, "L":0, "pts":1})
        rows.append({"team": row["away_team"], "group": group, "W":0, "D":1, "L":0, "pts":1})

points_df = pd.DataFrame(rows)

# Aggregate per team
table = (points_df
         .groupby(["group", "team"])
         .sum()
         .reset_index()
         .sort_values(["group", "pts"], ascending=[True, False]))

print(table)
# Out:
#    group                    team  W  D  L  pts
# 1      A                  Mexico  3  0  0    9
# 0      A          Czech Republic  1  0  2    3
# 2      A            South Africa  1  0  2    3
# 3      A             South Korea  1  0  2    3
# 5      B                  Canada  3  0  0    9
# 7      B             Switzerland  2  0  1    6
# 4      B  Bosnia and Herzegovina  1  0  2    3
# 6      B                   Qatar  0  0  3    0
# 11     C                Scotland  3  0  0    9
# 8      C                  Brazil  2  0  1    6
# 9      C                   Haiti  1  0  2    3
# 10     C                 Morocco  0  0  3    0
# 15     D                     USA  3  0  0    9
# 14     D                  Turkey  2  0  1    6
# 13     D                Paraguay  1  0  2    3
# 12     D               Australia  0  0  3    0
# 18     E                 Germany  3  0  0    9
# 19     E             Ivory Coast  2  0  1    6
# 17     E                 Ecuador  1  0  2    3
# 16     E                 Curaçao  0  0  3    0
# 21     F             Netherlands  2  0  1    6
# 22     F                  Sweden  2  0  1    6
# 23     F                 Tunisia  2  0  1    6
# 20     F                   Japan  0  0  3    0
# 24     G                 Belgium  3  0  0    9
# 25     G                   Egypt  2  0  1    6
# 26     G                    Iran  1  0  2    3
# 27     G             New Zealand  0  0  3    0
# 31     H                 Uruguay  3  0  0    9
# 30     H                   Spain  2  0  1    6
# 28     H              Cape Verde  1  0  2    3
# 29     H            Saudi Arabia  0  0  3    0
# 34     I                  Norway  3  0  0    9
# 32     I                  France  2  0  1    6
# 35     I                 Senegal  1  0  2    3
# 33     I                    Iraq  0  0  3    0
# 37     J               Argentina  3  0  0    9
# 36     J                 Algeria  2  0  1    6
# 38     J                 Austria  1  0  2    3
# 39     J                  Jordan  0  0  3    0
# 40     K                Colombia  3  0  0    9
# 42     K                Portugal  2  0  1    6
# 41     K                DR Congo  1  0  2    3
# 43     K              Uzbekistan  0  0  3    0
# 45     L                 England  3  0  0    9
# 44     L                 Croatia  2  0  1    6
# 46     L                   Ghana  1  0  2    3
# 47     L                  Panama  0  0  3    0

# %%
table.to_csv("group_stage_predictions.csv", index=False)
